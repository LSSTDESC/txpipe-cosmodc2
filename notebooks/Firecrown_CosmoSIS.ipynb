# %%
import sacc
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import astropy.io.fits as pf

# %%
Ccl_dir = '/global/homes/c/chihway/TXPipe/'
Cosmosis_dir = '/global/homes/c/chihway/txpipe-cosmodc2/cosmosis_config/test_output/'

# %%
for i in range(4):
    for j in range(i,4):
        ell_cosmosis = np.loadtxt(Cosmosis_dir+'shear_cl/ell.txt')
        cl_cosmosis = np.loadtxt(Cosmosis_dir+'shear_cl/bin_'+str(j+1)+'_'+str(i+1)+'.txt')
        ell_ccl = np.load(Ccl_dir+"cls('source_"+str(i)+"', 'source_"+str(j)+"').npz")['ell']
        cl_ccl = np.load(Ccl_dir+"cls('source_"+str(i)+"', 'source_"+str(j)+"').npz")['cl']
        plt.figure()
        plt.loglog(ell_cosmosis, ell_cosmosis*cl_cosmosis, label='cosmosis')
        plt.loglog(ell_ccl, ell_ccl*cl_ccl, label='ccl')
        plt.title(str(i)+str(j))
        plt.xlabel('ell')
        plt.ylabel('ell*Cell_shear')
        plt.ylim(5e-10, 1e-6)
        plt.xlim(1,100000)
        plt.legend()

# %%
for i in range(4):
    ell_cosmosis = np.loadtxt(Cosmosis_dir+'galaxy_shear_cl/ell.txt')
    cl_cosmosis = np.loadtxt(Cosmosis_dir+'galaxy_shear_cl/bin_1_'+str(i+1)+'.txt')
    ell_ccl = np.load(Ccl_dir+"cls('lens_0', 'source_"+str(i)+"').npz")['ell']
    cl_ccl = np.load(Ccl_dir+"cls('lens_0', 'source_"+str(i)+"').npz")['cl']
    plt.figure()
    plt.loglog(ell_cosmosis, ell_cosmosis*cl_cosmosis, label='cosmosis')
    plt.loglog(ell_ccl, ell_ccl*cl_ccl, label='ccl')
    plt.title(str(i)+str(j))
    plt.xlabel('ell')
    plt.ylabel('ell*Cell_galaxy_shear')
#     plt.ylim(1e-8, 1e-6)
    plt.xlim(1,100000)

    plt.legend()

# %%
ell_cosmosis = np.loadtxt(Cosmosis_dir+'galaxy_cl/ell.txt')
cl_cosmosis = np.loadtxt(Cosmosis_dir+'galaxy_cl/bin_1_1.txt')
ell_ccl = np.load(Ccl_dir+"cls('lens_0', 'lens_0').npz")['ell']
cl_ccl = np.load(Ccl_dir+"cls('lens_0', 'lens_0').npz")['cl']
plt.figure()
plt.loglog(ell_cosmosis, ell_cosmosis*cl_cosmosis, label='cosmosis')
plt.loglog(ell_ccl, ell_ccl*cl_ccl, label='ccl')
plt.xlabel('ell')
plt.ylabel('ell*Cell_galaxy_galaxy')
#     plt.ylim(1e-8, 1e-6)
plt.xlim(1,100000)

plt.legend()

# %%
# for i in range(4):
#     for j in range(i,4):
#         th_cosmosis = np.loadtxt(Cosmosis_dir+'shear_xi_plus/theta.txt')
#         xi_cosmosis = np.loadtxt(Cosmosis_dir+'shear_xi_plus/bin_'+str(j+1)+'_'+str(i+1)+'.txt')
# #         ell_ccl = np.load(Ccl_dir+"cls('source_"+str(i)+"', 'source_"+str(j)+"').npz")['ell']
# #         cl_ccl = np.load(Ccl_dir+"cls('source_"+str(i)+"', 'source_"+str(j)+"').npz")['cl']
#         plt.figure()
#         plt.loglog(th_cosmosis/np.pi*180*60, xi_cosmosis, label='cosmosis')
# #         plt.loglog(ell_ccl, ell_ccl*cl_ccl, label='ccl')
#         plt.title(str(i)+str(j))
#         plt.xlabel('th')
#         plt.ylabel('xi_shear')
#         plt.xlim(1,300)
#         plt.ylim(1e-7,3e-4)
#         plt.legend()

# %%
for i in range(4):

    z_cosmosis = np.loadtxt(Cosmosis_dir+'nz_source/z.txt')
    nz_cosmosis = np.loadtxt(Cosmosis_dir+'nz_source/bin_'+str(i+1)+'.txt')
    z_ccl = np.load(Ccl_dir+'nofz_source_'+str(i)+'.npz')['z']
    nz_ccl = np.load(Ccl_dir+'nofz_source_'+str(i)+'.npz')['nz']
    plt.figure()
    plt.plot(z_ccl, nz_ccl)
    plt.plot(z_cosmosis, nz_cosmosis/np.sum(nz_cosmosis))

    plt.title(str(i))
